# %%
# DOM Clobbering test
# Out:
# <form id="NOTEBOOK_DATA"><input name="html" value="<script>alert(1)</script>"></form>
# <img id="NOTEBOOK_DATA" src="x">
# <a id="config" href="http://attacker.test/">clobber</a>
