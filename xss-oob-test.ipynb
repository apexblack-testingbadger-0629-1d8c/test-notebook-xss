# %%
# OOB exfiltration test
# Out:
# <svg><use href="http://d9ehbtcvkge9aam28nigzfzd4bi1beah9.oast.me/svg-use"></use></svg>
# <svg><a href="http://d9ehbtcvkge9aam28nigzfzd4bi1beah9.oast.me/svg-click"><rect width="100%" height="50" fill="blue"/></a></svg>
# <table><td background="http://d9ehbtcvkge9aam28nigzfzd4bi1beah9.oast.me/td-bg">leak test</td></table>
# <svg><filter id="f"><feimage href="http://d9ehbtcvkge9aam28nigzfzd4bi1beah9.oast.me/filter"></feimage></filter><rect filter="url(#f)" width="100" height="100"/></svg>
# <img src="http://d9ehbtcvkge9aam28nigzfzd4bi1beah9.oast.me/img-src" width="1" height="1">
