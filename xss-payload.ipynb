# %%
# test
# Out:
# <svg xmlns="http://www.w3.org/2000/svg"><foreignObject width="100" height="100"><div xmlns="http://www.w3.org/1999/xhtml"><img src=x onerror="console.log("XSS")"></div></foreignObject></svg>

# %%
# css leak
# Out:
# <svg><svg><style>*{background-image:url(//evil.test/css-leak)}</style></svg></svg>
